# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the dataset from CSV file
df=pd.read_csv('/content/StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# Select the first 50 rows for analysis
df=df.head(50)
df
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %%
# Check the shape of the dataset (rows, columns)
df.shape
df.shape
# Out:
# (50, 8)

# %%
#  Check the data types, non-null counts, and memory usage
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       50 non-null     object
#  1   race/ethnicity               50 non-null     object
#  2   parental level of education  50 non-null     object
#  3   lunch                        50 non-null     object
#  4   test preparation course      50 non-null     object
#  5   math score                   50 non-null     int64
#  6   reading score                50 non-null     int64
#  7   writing score                50 non-null     int64
# dtypes: int64(3), object(5)
# memory usage: 3.3+ KB

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.tail()
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 45    male        group B          associate's degree      standard
# 46  female        group A          associate's degree      standard
# 47  female        group C                 high school      standard
# 48  female        group D          associate's degree  free/reduced
# 49    male        group C                 high school      standard
#
#    test preparation course  math score  reading score  writing score
# 45                    none          65             54             57
# 46               completed          55             65             62
# 47                    none          66             71             76
# 48               completed          57             74             76
# 49               completed          82             84             82

# %%
# Generate summary statistics for numeric columns (mean, min, max)
df.describe()
# Out:
#        math score  reading score  writing score
# count   50.000000      50.000000      50.000000
# mean    62.840000      67.940000      66.440000
# std     15.163544      14.261995      14.785763
# min     18.000000      32.000000      28.000000
# 25%     54.250000      57.250000      57.000000
# 50%     65.000000      70.000000      67.500000
# 75%     71.750000      75.000000      76.000000
# max     97.000000      95.000000      93.000000

# %%
# Check for missing values in the dataset
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
# Check for duplicate rows in the dataset
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Convert the 'math score' column to a NumPy array
maths_score=df['math score'].to_numpy()
maths_score
# Out:
# array([72, 69, 90, 47, 76, 71, 88, 40, 64, 38, 58, 40, 65, 78, 50, 69, 88,
#        18, 46, 54, 66, 65, 44, 69, 74, 73, 69, 67, 70, 62, 69, 63, 56, 40,
#        97, 81, 74, 50, 75, 57, 55, 58, 53, 59, 50, 65, 55, 66, 57, 82])

# %%
# Convert the 'reading score' column to a NumPy array
reading_score=df['reading score'].to_numpy()
reading_score
# Out:
# array([72, 90, 95, 57, 78, 83, 95, 43, 64, 60, 54, 52, 81, 72, 53, 75, 89,
#        32, 42, 58, 69, 75, 54, 73, 71, 74, 54, 69, 70, 70, 74, 65, 72, 42,
#        87, 81, 81, 64, 90, 56, 61, 73, 58, 65, 56, 54, 65, 71, 74, 84])

# %%
# Convert the 'writing score' column to a NumPy array
writing_score=df['writing score'].to_numpy()
writing_score
# Out:
# array([74, 88, 93, 44, 75, 78, 92, 39, 67, 50, 52, 43, 73, 70, 58, 78, 86,
#        28, 46, 61, 63, 70, 53, 73, 80, 72, 55, 75, 65, 75, 74, 61, 65, 38,
#        82, 79, 83, 59, 88, 57, 54, 68, 65, 66, 54, 57, 62, 76, 76, 82])

# %%
# Calculate total marks for each student by adding all three subjects
total=maths_score+reading_score+writing_score
total[:10]
# Out:
# array([218, 247, 278, 148, 229, 232, 275, 122, 195, 148])

# %%
# Calculate the average score for each subject
average=[np.mean(maths_score),np.mean(reading_score),np.mean(writing_score)]
average
# Out:
# [np.float64(62.84), np.float64(67.94), np.float64(66.44)]

# %%
# Average score by gender
gender_average=df.groupby('gender')[['math score','reading score','writing score']].mean()
gender_average
# Out:
#         math score  reading score  writing score
# gender
# female   61.962963      71.259259      70.259259
# male     63.869565      64.043478      61.956522

# %%
# Plot gender-wise average
gender_average.plot(kind='bar',figsize=(6,4),color=['darkorange','grey','seagreen'])
plt.title('Average Scores by Gender')
plt.ylabel('Average Score')
plt.legend(title='Subjects')
plt.show()

# %%
# Group by parental level of education
parent_average = df.groupby('parental level of education')[['math score','reading score','writing score']].mean()
parent_average
# Out:
#                              math score  reading score  writing score
# parental level of education
# associate's degree            59.375000      65.812500      63.812500
# bachelor's degree             71.000000      70.666667      76.333333
# high school                   67.375000      73.500000      70.250000
# master's degree               62.833333      67.666667      68.166667
# some college                  65.923077      68.769231      66.384615
# some high school              51.500000      61.000000      59.500000

# %%
# Plot
parent_average.plot(kind='bar', figsize=(10,5), color=['grey','lightblue','steelblue'])
plt.title('Average Scores by Parental Education Level')
plt.ylabel('Average Score')
plt.xlabel('Parental Education')
plt.legend(title='Subjects')
plt.show()

# %%
# Group by test preparation course
testprep_average=df.groupby('test preparation course')[['math score','reading score','writing score']].mean()
testprep_average
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                 68.692308      74.461538      74.307692
# none                      60.783784      65.648649      63.675676

# %%
# Plot
testprep_average.plot(kind='bar', figsize=(6,4))
plt.title('Average Scores by Test Preparation Course')
plt.ylabel('Average Score')
plt.xlabel('Test Preparation')
plt.legend(title='Subjects')
plt.show()

# %%
# Group by lunch type
lunch_average=df.groupby('lunch')[['math score','reading score','writing score']].mean()
lunch_average
# Out:
#               math score  reading score  writing score
# lunch
# free/reduced   54.333333      61.888889      59.777778
# standard       67.625000      71.343750      70.187500

# %%
# Plot
lunch_average.plot(kind='bar', figsize=(6,4), color=['blue','green','orange'])
plt.title('Average Scores by Lunch Type')
plt.ylabel('Average Score')
plt.xlabel('Lunch Type')
plt.legend(title='Subjects')
plt.show()

# %%
# Plot a bar chart of average scores for Math, Reading, and Writing
average=[np.mean(maths_score),np.mean(reading_score),np.mean(writing_score)]
subjects=['Math','Reading','Writing']
plt.bar(subjects,average,color=['blue','green','darkorange'])
plt.title('Average Scores')
plt.ylabel('Average Score')
plt.show()

# %%
# Show first 5 rows of data where gender is female
df[df['gender'].isin(['female'])].head(5)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
# 5  female        group B          associate's degree  standard
# 6  female        group B                some college  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 5                    none          71             83             78
# 6               completed          88             95             92

# %%
# Show first 5 rows of data where math score is between 60 and 80
df[df['math score'].between(60,80)].head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 8    male        group D                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 4                    none          76             78             75
# 5                    none          71             83             78
# 8               completed          64             64             67
